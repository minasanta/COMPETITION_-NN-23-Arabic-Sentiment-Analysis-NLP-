# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from tensorflow.keras import Model
from keras.layers import (
    Embedding,
    Dense,
    Dropout,
    MultiHeadAttention,
    LayerNormalization,
    Input,
    GlobalAveragePooling1D,
)
from keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers
from nltk.stem import ISRIStemmer
import string, re, functools, operator
import pyarabic.araby as ar
from nltk.tokenize import RegexpTokenizer
from sklearn.metrics import accuracy_score, classification_report
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, RegexpTokenizer
from keras.optimizers import Adam

# %%
file_path = "train.xlsx"
df_train = pd.read_excel(file_path)
df_train
# Out:
#                                       review_description  rating
# 0      شركه زباله و سواقين بتبرشم و مفيش حتي رقم للشك...      -1
# 1      خدمة الدفع عن طريق الكي نت توقفت عندي اصبح فقط...       1
# 2      تطبيق غبي و جاري حذفه ، عاملين اكواد خصم و لما...      -1
# 3      فعلا تطبيق ممتاز بس لو فى امكانية يتيح لمستخدم...       1
# 4      سيء جدا ، اسعار رسوم التوصيل لا تمت للواقع ب ص...      -1
# ...                                                  ...     ...
# 32031  التطبيق اصبح سيء للغايه نقوم بطلب لا يتم وصول ...      -1
# 32032                                         y love you       1
# 32033      الباقه بتخلص وبشحن مرتين باقه اضافيه ١٠٠ جنيه      -1
# 32034  تطبيق فاشل وصلني الطلب ناقص ومش ينفع اعمل حاجة...      -1
# 32035                                    ليش ما يفتح معي       1
#
# [32036 rows x 2 columns]

# %%
arabic_stop_words = [
    "و", "في", "من", "على", "إلى", "لا", "أو", "هو", "هي", "يكون",
    "أنا", "أنت", "هو", "هي", "نحن", "أنتم", "هم",
    "عن", "مع", "كما", "مثل", "بين", "إذا", "حتى", "منذ",
    "و", "أو", "لكن", "إذا", "إن",
    "اليوم", "غداً", "الآن", "ثم", "بعد",
    "كان", "يكون", "أصبح", "صار", "ليس", "لم",
    "هذا", "هذه", "ذلك", "تلك", 
    "كل", "على", "فيه", "منه", "عنه", "له", "به", "إليه", "لها", "فيها",
    "بها", "منها", "عنها", "إليها", "الذي", "التي", "اللذين", "اللذان", "اللتان",
    "اللتين", "هؤلاء", "ذلك", "هذه", "هذا", "تلك", "تحت", "فوق", "معه", "لديه",
    "عليه", "عليها", "أي", "هل", "إذا", "ماذا", "هناك", "هنالك", "إلى",
    "يناير", "فبراير", "مارس", "إبريل", "مايو", "يونيو", "يوليو", "أغسطس", "سبتمبر", "أكتوبر", "نوفمبر", "ديسمبر",
    "الأحد", "الاثنين", "الثلاثاء", "الأربعاء", "الخميس", "الجمعة", "السبت"
]

# %%
import Stemmer
st = Stemmer.Stemmer("arabic")


def text_cleaning(text, stemmer=st):
    # remove stop words and punctuation

    text = text.lower()
    text = re.sub(r"\s+", " ", text)
    text = re.sub("(\s\d+)", "", text)
    text = re.sub(r"$\d+\W+|\b\d+\b|\W+\d+$", "", text)
    text = re.sub("\d+", " ", text)
    text = ar.strip_tashkeel(text)
    text = ar.strip_tatweel(text)
    text = text.replace("#", " ")
    text = text.replace("@", " ")
    text = text.replace("_", " ")

    tokenizer = RegexpTokenizer(r"\w+")

    words = tokenizer.tokenize(text)

    stop_words = set(string.punctuation).union(set(arabic_stop_words))

    filtered_list = [word for word in words if word.casefold() not in stop_words]

    # word stemming
    stem_words = [stemmer.stemWord(word) for word in filtered_list]

    text = " ".join(map(str, stem_words))
    text = text.replace("آ", "ا")
    text = text.replace("إ", "ا")
    text = text.replace("أ", "ا")
    text = text.replace("ؤ", "و")
    text = text.replace("ئ", "ي")

    return text


df_train["new review_description"] = df_train["review_description"].apply(
    lambda text: text_cleaning(text)
)


df_train.head(20)
# Out:
#                                    review_description  rating  \
# 0   شركه زباله و سواقين بتبرشم و مفيش حتي رقم للشك...      -1
# 1   خدمة الدفع عن طريق الكي نت توقفت عندي اصبح فقط...       1
# 2   تطبيق غبي و جاري حذفه ، عاملين اكواد خصم و لما...      -1
# 3   فعلا تطبيق ممتاز بس لو فى امكانية يتيح لمستخدم...       1
# 4   سيء جدا ، اسعار رسوم التوصيل لا تمت للواقع ب ص...      -1
# 5   قعد عشرين سنة يدور على سائق بس اما عن توصيل ال...       0
# 6                                          احلئ تطبيق       1
# 7                                       رائع واو مدهش       1
# 8   مکو بس البحرین وعمان وغیرهه بس العراق مکو یعنی...      -1
# 9                     تطبيق جميل يستاهل الخمس نجوم👍👍👍       1
# 10                                          هلا طلبات       1
# 11                              الاسمر عمار الريق مصر       1
# 12  ممتاز ومصدقة ودقه وسرعة في التوصيل الرجاء وضع ...       1
# 13                                     هالبرنامج منقذ       1
# 14            مرة سريع جاني الطلب حار انصح فيه بصراحة       1
# 15                                           يو ار يو       1
# 16                                   ما يوصل لأي مكان      -1
# 17  لو سمحت انا سالت قبل كده إذا كان في توصيل لمنط...      -1
# 18                            افضل تطبيق علی مر تاريخ       1
# 19  طلبت طلبيه لي ساعه ويوم اتصلت عليهم قالو طلبكم...      -1
#
#                                new review_description
# 0   شرك زبال سواق تبرشم مفيش حت رقم شكاو سواق يسيب...
# 1       خدم دفع طريق الك نت توقف عند اصبح فقط دفع نقد
# 2   تطبيق غب جار حذف عامل اكواد خصم لما استخدم اكت...
# 3   فعل تطبيق ممتاز بس لو في امكان يتيح لمستخدم تط...
# 4             سيء جدا اسعار رسوم توصيل تمت واقع ب صله
# 5   قعد عشرين سنة يدور سايق بس اما توصيل اشياء جيد...
# 6                                          احلء تطبيق
# 7                                       رايع واو مدهش
# 8   مکو بس بحری عمان غیر بس عراق مکو یعنی نجم وحد ...
# 9                          تطبيق جميل استاهل خمس نجوم
# 10                                           هلا طلبا
# 11                                  اسمر عمار ريق مصر
# 12  ممتاز مصدق ودق سرع توصيل رجاء وضع تقيم وجب او ...
# 13                                     هالبرنامج منقذ
# 14                     مرة سريع جان طلب حار انصح صراح
# 15                                           يو ار يو
# 16                                    ما يوصل لء مكان
# 17  لو سمح انا سال قبل كده توصيل لمنطق شتىل نقط شت...
# 18                            افضل تطبيق علی مر تاريخ
# 19  طلب طلب لي ساع يوم اتصل علي قالو طلب لغي حيوان...

# %%
X = df_train["new review_description"]
y = df_train["rating"].astype(int) + 1

# %%
tokenizer = Tokenizer(oov_token="<UNK>")
tokenizer.fit_on_texts(X)
total_words = len(tokenizer.word_index) + 1

# %%
sequences = tokenizer.texts_to_sequences(X)
max_len = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    padded_sequences, y, test_size=0.2, random_state=42, stratify=y
)
num_classes = 3
y_train = np.array(y_train)
y_val = np.array(y_val)
print("X_train shape :", X_train.shape)
print("y_train shape :", y_train.shape)
print("X_val shape :", X_val.shape)
print("y_val shape :", y_val.shape)
print('Total Vocabulary Size (Untrimmed): %d' % total_words)
print('max_len: %d' % max_len)
# Out:
# X_train shape : (31036, 318)
# y_train shape : (31036,)
# X_val shape : (1000, 318)
# y_val shape : (1000,)
# Total Vocabulary Size (Untrimmed): 22752
# max_len: 318

# %%
embed_dim = 32
num_heads = 10
ff_dim = 16
max_len = 318  
total_words = 22752 

# Token and Position Embedding
inputs = Input(shape=(max_len,))
token_emb = Embedding(input_dim=total_words, output_dim=embed_dim)(inputs)

positions = tf.range(start=0, limit=max_len, delta=1)
pos_emb = Embedding(input_dim=max_len, output_dim=embed_dim)(positions)

x = token_emb + pos_emb

# Encoder Block
attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(x, x)
attn_output = Dropout(0.5)(attn_output)
out1 = LayerNormalization(epsilon=1e-6)(x + attn_output)

ffn_output = Sequential([Dense(ff_dim, activation="relu"), Dense(embed_dim)])(out1)

ffn_output = Dropout(0.5)(ffn_output)
x = LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

# Global Average Pooling and Dense layers
x = GlobalAveragePooling1D()(x)
x = Dropout(0.5)(x)
x = Dense(ff_dim, activation="relu")(x)
x = Dropout(0.5)(x)
outputs = Dense(3, activation="softmax")(
    x
)  # Adjust the output size for the number of classes

# Build the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(
    tf.keras.optimizers.Adam(0.0001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# Print the model summary
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 318)]        0           []
#
#  embedding_4 (Embedding)        (None, 318, 32)      728064      ['input_3[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 318, 32)     0           ['embedding_4[0][0]']
#  mbda)
#
#  multi_head_attention_2 (MultiH  (None, 318, 32)     41952       ['tf.__operators__.add_6[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 318, 32)      0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 318, 32)     0           ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'dropout_8[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 318, 32)     64          ['tf.__operators__.add_7[0][0]']
#  rmalization)
#
#  sequential_2 (Sequential)      (None, 318, 32)      1072        ['layer_normalization_4[0][0]']
#
#  dropout_9 (Dropout)            (None, 318, 32)      0           ['sequential_2[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 318, 32)     0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'dropout_9[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 318, 32)     64          ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  global_average_pooling1d_2 (Gl  (None, 32)          0           ['layer_normalization_5[0][0]']
#  obalAveragePooling1D)
#
#  dropout_10 (Dropout)           (None, 32)           0           ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 16)           528         ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 16)           0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 3)            51          ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 771,795
# Trainable params: 771,795
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# %%
checkpoint = ModelCheckpoint(
    filepath="./models_hdf5/transformer.hdf5",
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
)

history = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=32,
    validation_data=(X_val, y_val),
    class_weight=class_weight_dict,
    callbacks=[checkpoint],
)
# Out:
# Epoch 1/30
# 970/970 [==============================] - 54s 56ms/step - loss: 1.1166 - accuracy: 0.2786 - val_loss: 1.0774 - val_accuracy: 0.3540
# Epoch 2/30
# 970/970 [==============================] - 53s 55ms/step - loss: 1.1022 - accuracy: 0.2772 - val_loss: 1.0982 - val_accuracy: 0.3530
# Epoch 3/30
# 970/970 [==============================] - 54s 56ms/step - loss: 1.1023 - accuracy: 0.2780 - val_loss: 1.0840 - val_accuracy: 0.3540
# Epoch 4/30
# 970/970 [==============================] - 53s 55ms/step - loss: 1.1028 - accuracy: 0.2514 - val_loss: 1.1052 - val_accuracy: 0.0470
# Epoch 5/30
# 970/970 [==============================] - 53s 54ms/step - loss: 1.1006 - accuracy: 0.2336 - val_loss: 1.1059 - val_accuracy: 0.0470
# Epoch 6/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.1010 - accuracy: 0.2011 - val_loss: 1.1064 - val_accuracy: 0.0470
# Epoch 7/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.0999 - accuracy: 0.2087 - val_loss: 1.1052 - val_accuracy: 0.0470
# Epoch 8/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.1007 - accuracy: 0.1868 - val_loss: 1.1067 - val_accuracy: 0.0470
# Epoch 9/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.1002 - accuracy: 0.1919 - val_loss: 1.1055 - val_accuracy: 0.0470
# Epoch 10/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.1003 - accuracy: 0.1870 - val_loss: 1.1057 - val_accuracy: 0.0470
# Epoch 11/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.1007 - accuracy: 0.1945 - val_loss: 1.1068 - val_accuracy: 0.0470
# Epoch 12/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.1007 - accuracy: 0.1616 - val_loss: 1.1071 - val_accuracy: 0.0470
# Epoch 13/30
# 970/970 [==============================] - 53s 54ms/step - loss: 1.0991 - accuracy: 0.1555 - val_loss: 1.1063 - val_accuracy: 0.0470
# Epoch 14/30
# 970/970 [==============================] - 53s 54ms/step - loss: 1.0993 - accuracy: 0.1659 - val_loss: 1.1066 - val_accuracy: 0.0470
# Epoch 15/30
# 970/970 [==============================] - 53s 54ms/step - loss: 1.0992 - accuracy: 0.1520 - val_loss: 1.1063 - val_accuracy: 0.0470
# Epoch 16/30
# 970/970 [==============================] - 53s 54ms/step - loss: 1.0997 - accuracy: 0.1636 - val_loss: 1.1059 - val_accuracy: 0.0480
# Epoch 17/30
# 970/970 [==============================] - 54s 56ms/step - loss: 1.0992 - accuracy: 0.1579 - val_loss: 1.1054 - val_accuracy: 0.0470
# Epoch 18/30
# 970/970 [==============================] - 53s 54ms/step - loss: 1.0992 - accuracy: 0.1456 - val_loss: 1.1051 - val_accuracy: 0.0480
# Epoch 19/30
# 970/970 [==============================] - 53s 54ms/step - loss: 1.0985 - accuracy: 0.1655 - val_loss: 1.1009 - val_accuracy: 0.2010
# Epoch 20/30
# 970/970 [==============================] - 52s 54ms/step - loss: 1.0990 - accuracy: 0.1587 - val_loss: 1.1013 - val_accuracy: 0.1060
# Epoch 21/30
# 970/970 [==============================] - 52s 53ms/step - loss: 1.0947 - accuracy: 0.1952 - val_loss: 1.0638 - val_accuracy: 0.3100
# Epoch 22/30
# 970/970 [==============================] - 51s 52ms/step - loss: 1.0310 - accuracy: 0.3803 - val_loss: 0.9039 - val_accuracy: 0.7110
# Epoch 23/30
# 970/970 [==============================] - 50s 52ms/step - loss: 0.9951 - accuracy: 0.4669 - val_loss: 0.7920 - val_accuracy: 0.7440
# Epoch 24/30
# 970/970 [==============================] - 50s 52ms/step - loss: 0.9808 - accuracy: 0.5434 - val_loss: 0.7885 - val_accuracy: 0.7350
# Epoch 25/30
# 970/970 [==============================] - 50s 52ms/step - loss: 0.9391 - accuracy: 0.5801 - val_loss: 0.7139 - val_accuracy: 0.7440
# Epoch 26/30
# 970/970 [==============================] - 50s 52ms/step - loss: 0.9183 - accuracy: 0.5977 - val_loss: 0.7759 - val_accuracy: 0.5220
# Epoch 27/30
# 970/970 [==============================] - 50s 52ms/step - loss: 0.8860 - accuracy: 0.6308 - val_loss: 0.7206 - val_accuracy: 0.7300
# Epoch 28/30
# 970/970 [==============================] - 50s 52ms/step - loss: 0.8646 - accuracy: 0.6439 - val_loss: 0.8111 - val_accuracy: 0.5350
# Epoch 29/30
# 970/970 [==============================] - 52s 53ms/step - loss: 0.8468 - accuracy: 0.6400 - val_loss: 0.7715 - val_accuracy: 0.5690
# Epoch 30/30
# 970/970 [==============================] - 54s 56ms/step - loss: 0.8268 - accuracy: 0.6592 - val_loss: 0.6614 - val_accuracy: 0.7580

# %%
model.load_weights("./models_hdf5/transformer.hdf5")
loss, accuracy = model.evaluate(X_val, y_val)
print(f"Validation Loss: {loss}, Validation Accuracy: {accuracy}")
# Out:
# 32/32 [==============================] - 1s 23ms/step - loss: 0.6614 - accuracy: 0.7580
# Validation Loss: 0.6614454388618469, Validation Accuracy: 0.7580000162124634

# %%
file_path = "test _no_label.csv" # Path on Kaggle: /kaggle/input/arabic-sentiment-analysis-nlp/test _no_label.csv
df_test = pd.read_csv(file_path)
df_test
# Out:
#        ID                                 review_description
# 0       1  اهنئكم على خدمه العملاء في المحادثه المباشره م...
# 1       2  ممتاز جدا ولكن اتمنى ان تكون هناك بعض المسابقا...
# 2       3    كل محملته يقول تم ايقاف حطيت2 عشان تسوون الخطاء
# 3       4                                            شغل طيب
# 4       5                                         بعد ماجربت
# ..    ...                                                ...
# 995   996                                              يستهل
# 996   997                             خدمة سيئة بكل المعايير
# 997   998                                      لؤي٠٣٣٢لؤ٣٤٣س
# 998   999                     تطبيق غير صادق ف خصم الكوبونات
# 999  1000  تأخير + الموظفين غير مؤهلة .للأسف انا استخدم ط...
#
# [1000 rows x 2 columns]

# %%
df_test["new review_description"] = df_test["review_description"].apply(
    lambda x: text_cleaning(x)
)
df_test.head(20)
# Out:
#     ID                                 review_description  \
# 0    1  اهنئكم على خدمه العملاء في المحادثه المباشره م...
# 1    2  ممتاز جدا ولكن اتمنى ان تكون هناك بعض المسابقا...
# 2    3    كل محملته يقول تم ايقاف حطيت2 عشان تسوون الخطاء
# 3    4                                            شغل طيب
# 4    5                                         بعد ماجربت
# 5    6                                           وايد زين
# 6    7                                        سيئ جدا جدا
# 7    8  تطبيق ضعيف لا يليق بشركه كبيره مثل رأيه واغلب ...
# 8    9                                              ٠ ٠ؤ٩
# 9   10  السواقين بيكدبوا ومبيجوش وبيكنسلوا الرحلات مع ...
# 10  11                                  يستحق 5نجوم واكثر
# 11  12                                             رائع .
# 12  13                والله برنامج جدآ رائع ارجوكم استمره
# 13  14              انا طلبت وجبه مع ببسي وصل الساعة سبعة
# 14  15  أنا عايشه بصلاله،يعني ما في إلا ثلاث مطاعم بصل...
# 15  16                                           ني هتيعز
# 16  17                                         Very bad 👎
# 17  18  المنطقة التي انا فيها لا تدعم التطبيق الاردن/ع...
# 18  19        المشكله لاتوجد صور للوجبات ..فقط البعض منها
# 19  20  ياعمي توصيل ساعه ونص وبعد انتهاء الوقت لم يقبل...
#
#                                new review_description
# 0   اهنء خدم عملاء محادثه مباشره ما قصرو الله يوفق...
# 1   ممتاز جدا ولك اتمني ان تكون بعض مسابق والجوايز...
# 2              محمل يقول تم ايقاف حطي عشان تسوون خطاء
# 3                                             شغل طيب
# 4                                               ماجرب
# 5                                            وايد زين
# 6                                         سيء جدا جدا
# 7   تطبيق ضعيف يليق بشر كبير راي واغلب وقت عند است...
# 8                                                   ء
# 9   سواق يكدب مبيجوش يكنسل رحل نفس انصح اوبر والل ...
# 10                                    استحقنجوم واكثر
# 11                                               رايع
# 12                      والل رنامج جدء رايع ارج استمر
# 13                        انا طلب وجب ببس وصل ساع سبع
# 14  عايش صلال يعن ما الا ثلاث مطاعم صلال ليش صلال ...
# 15                                           ني هتيعز
# 16                                           very bad
# 17         منطق انا تدعم تطبيق ارد عمان موقر ذهيب شرق
# 18                       مشكله لاتوجد صور وجب فقط بعض
# 19  ياعم توصيل ساع ونص بعد انتهاء وقت يقبل طلب تطب...

# %%
sequences_test = tokenizer.texts_to_sequences(df_test["new review_description"])
padded_sequences_test = pad_sequences(sequences_test, maxlen=max_len)

predictions = model.predict(padded_sequences_test)
predicted_labels = np.argmax(predictions, axis=1) - 1

output_df = pd.DataFrame({"ID": df_test["ID"], "rating": predicted_labels})

output_df.to_csv("./results/test_results_transformer.csv", index=False)
# Out:
# 32/32 [==============================] - 1s 20ms/step

# %%
output_df["review_description"] = df_test["review_description"]
output_df.sample(n=20)
# Out:
#       ID  rating                                 review_description
# 620  621       1                                        رائعه وسهله
# 634  635       1                                            راع جدا
# 853  854      -1  زي الزفت وفي مشكله وبعمل خلل في الجهاز ومش بير...
# 917  918       1                             ممتاز انصحكم بل تحميله
# 723  724      -1  مش التطبيق المفروض للمصريين طيب ليه اللغة الإن...
# 52    53       0                                            سيا سيا
# 63    64       0      طلبات تاخير في كل وقت ومافي متابعة من الادارة
# 729  730       0                            خدمة التوصيل جدا بطيئه👎
# 69    70       0  السعر ( اغلا) والجوده ليست كالتي نشتريها بأنفس...
# 193  194       1  البرنامج حلو جداً بس عايزين منتجات الرجوع للمدرسة
# 476  477       1                                        ما شاء الله
# 615  616       0                                 عدلو تاخير الطلبات
# 55    56       1                                               Baad
# 388  389       1                                   ممتاز خدمة رائعة
# 915  916       1                                          انهو رائع
# 239  240       0                                        خراااا اووى
# 348  349       1                                        عنجد بتجننن
# 546  547       1               تطبيق فوق الممتاز يستحق التحميل رائع
# 859  860      -1  فيه مشاكل فى الابليكيشن لازم تصليحها مثلا احجز...
# 652  653       1                                      شكرا علي ردك.
